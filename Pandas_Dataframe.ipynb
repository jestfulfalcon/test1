# %% [markdown]
# <a href="https://colab.research.google.com/github/jestfulfalcon/test1/blob/main/Pandas_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pandas DataFrame will be created by loading the datasets from existing storage, storage can be SQL Database, CSV file, and Excel file.

# %%
import pandas as pd

# %%
import numpy as np

# %%
lst=['Geeks','for','geeks','is','portal','for','geeks']
pd.DataFrame(lst)
# Out:
#         0
# 0   Geeks
# 1     for
# 2   geeks
# 3      is
# 4  portal
# 5     for
# 6   geeks

# %% [markdown]
# **Creating DataFrame from dict of ndarray/lists**

# %%
data={'name':['Tom','Jeery','Nick','Krish'] , 'age':[20,34,45,33] }
pd.DataFrame(data)
# Out:
#     name  age
# 0    Tom   20
# 1  Jeery   34
# 2   Nick   45
# 3  Krish   33

# %% [markdown]
# A Data frame is a two-dimensional data structure, i.e., data is aligned in a tabular fashion in rows and columns. We can perform basic operations on rows/columns like selecting, deleting, adding, and renaming.

# %%
data = { 'Name'         :['Jai', 'Princi', 'Gaurav', 'Anuj'],
         'Age'          :[27, 24, 22, 32],
         'Address'      :['Delhi', 'Kanpur', 'Allahabad', 'Kannauj'],
         'Qualification':['Msc', 'MA', 'MCA', 'Phd']}

df=pd.DataFrame(data)
df[['Name','Qualification']]
# Out:
#      Name Qualification
# 0     Jai           Msc
# 1  Princi            MA
# 2  Gaurav           MCA
# 3    Anuj           Phd

# %% [markdown]
# **Slicing in DataFrames Using iloc and loc**

# %%
data = {'one'   : pd.Series([1, 2, 3, 4]),
        'two'   : pd.Series([10, 20, 30, 40]),
        'three' : pd.Series([100, 200, 300, 400]),
        'four'  : pd.Series([1000, 2000, 3000, 4000])}
df=pd.DataFrame(data)

df
# Out:
#    one  two  three  four
# 0    1   10    100  1000
# 1    2   20    200  2000
# 2    3   30    300  3000
# 3    4   40    400  4000

# %%
df.loc[1:2 , 'two':'three'] # in loc we are including index of row and column whichj i want to include
# Out:
#    two  three
# 1   20    200
# 2   30    300

# %%
df.iloc[1:-1 , 1:-1] # iloc function excluding 2nd
# Out:
#    two  three
# 1   20    200
# 2   30    300

# %%
df.iloc[: , 2:3]
# Out:
#    three
# 0    100
# 1    200
# 2    300
# 3    400

# %%
df.iloc[[0,2],[1,3]] # accessing specific rows
# Out:
#    two  four
# 0   10  1000
# 2   30  3000

# %% [markdown]
# Slicing using conditions

# %%
df.loc[df['two']>20 , ['three','four']]
# Out:
#    three  four
# 2    300  3000
# 3    400  4000

# %%
df.loc[df['three'] < 300, ['one','four']]
# Out:
#    one  four
# 0    1  1000
# 1    2  2000

# %% [markdown]
# **Column Adiition**
#  three ways how we can add column here
#
# Using List
# Using Pandas Series
# Using an existing Column(we can modify that column in the way we want and that modified part can also be displayed)

# %%
l=[22,34,56,76]
df['five']=l
df
# Out:
#    one  two  three  four  five
# 0    1   10    100  1000    22
# 1    2   20    200  2000    34
# 2    3   30    300  3000    56
# 3    4   40    400  4000    76

# %%
sr=pd.Series([100,344,23,45])
df['six']=sr
df
# Out:
#    one  two  three  four  five  six
# 0    1   10    100  1000    22  100
# 1    2   20    200  2000    34  344
# 2    3   30    300  3000    56   23
# 3    4   40    400  4000    76   45

# %%
df['seven']=df['one'] + 10
df
# Out:
#    one  two  three  four  five  six  seven
# 0    1   10    100  1000    22  100     11
# 1    2   20    200  2000    34  344     12
# 2    3   30    300  3000    56   23     13
# 3    4   40    400  4000    76   45     14

# %% [markdown]
# **Column Deletion**
# using pop and del

# %%
df
# Out:
#    one  two  three  four  five  six  seven
# 0    1   10    100  1000    22  100     11
# 1    2   20    200  2000    34  344     12
# 2    3   30    300  3000    56   23     13
# 3    4   40    400  4000    76   45     14

# %%
del df['one']
df
# Out:
#    two  three  four  five  six  seven
# 0   10    100  1000    22  100     11
# 1   20    200  2000    34  344     12
# 2   30    300  3000    56   23     13
# 3   40    400  4000    76   45     14

# %%
df.pop('six')
df
# Out:
#    two  three  four  five  seven
# 0   10    100  1000    22     11
# 1   20    200  2000    34     12
# 2   30    300  3000    56     13
# 3   40    400  4000    76     14

# %% [markdown]
# **Addition of Rows**

# %%
df1=pd.DataFrame([[1,2],[3,4]], columns=['a','b'])
df2=pd.DataFrame([[5,6],[7,8]], columns=['a','b'])

df3=pd.concat([df1,df2] , ignore_index=True)
df3
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 2  5  6
# 3  7  8

# %% [markdown]
# **Pandas drop function**

# %%
data = { 'one'   : pd.Series([1, 2, 3, 4]),
         'two'   : pd.Series([10, 20, 30, 40]),
         'three' : pd.Series([100, 200, 300, 400]),
         'four'  : pd.Series([1000, 2000, 3000, 4000])}


df = pd.DataFrame(data)
df
# Out:
#    one  two  three  four
# 0    1   10    100  1000
# 1    2   20    200  2000
# 2    3   30    300  3000
# 3    4   40    400  4000

# %%
df.drop([0,1] , axis=0 , inplace=True)
df
# Out:
#    one  two  three  four
# 2    3   30    300  3000
# 3    4   40    400  4000

# %%
df.drop(['one','three'], axis = 1, inplace = True)
df
# Out:
#    two  four
# 2   30  3000
# 3   40  4000

# %% [markdown]
# **Transposing a DataFrame**

# %%
data = { 'one'   : pd.Series([1, 2, 3, 4]),
         'two'   : pd.Series([10, 20, 30, 40]),
         'three' : pd.Series([100, 200, 300, 400]),
         'four'  : pd.Series([1000, 2000, 3000, 4000])}

df = pd.DataFrame(data)
df
# Out:
#    one  two  three  four
# 0    1   10    100  1000
# 1    2   20    200  2000
# 2    3   30    300  3000
# 3    4   40    400  4000

# %%
df.T
# Out:
#           0     1     2     3
# one       1     2     3     4
# two      10    20    30    40
# three   100   200   300   400
# four   1000  2000  3000  4000

# %% [markdown]
# **A set of more DataFrame Functionalities**

# %%
df
# Out:
#    one  two  three  four
# 0    1   10    100  1000
# 1    2   20    200  2000
# 2    3   30    300  3000
# 3    4   40    400  4000

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=4, step=1),
#  Index(['one', 'two', 'three', 'four'], dtype='object')]

# %%
df.ndim
# Out:
# 2

# %%
df.dtypes
# Out:
# one      int64
# two      int64
# three    int64
# four     int64
# dtype: object

# %%
df.shape
# Out:
# (4, 4)

# %% [markdown]
# **head function**

# %%
d = { 'Name'  :pd.Series(['Tom','Jerry','Spike','Popeye','Olive','Bluto','Mickey']),
      'Age'   :pd.Series([10,12,14,30,28,33,15]),
      'Height':pd.Series([3.25,1.11,4.12,5.47,6.15,6.67,2.61])}

df= pd.DataFrame(d)
df
# Out:
#      Name  Age  Height
# 0     Tom   10    3.25
# 1   Jerry   12    1.11
# 2   Spike   14    4.12
# 3  Popeye   30    5.47
# 4   Olive   28    6.15
# 5   Bluto   33    6.67
# 6  Mickey   15    2.61

# %%
df.head() #by default print first five rows only
df.head(3) # first 3 rows
# Out:
#     Name  Age  Height
# 0    Tom   10    3.25
# 1  Jerry   12    1.11
# 2  Spike   14    4.12

# %%
df.tail(3) # last ones
# Out:
#      Name  Age  Height
# 4   Olive   28    6.15
# 5   Bluto   33    6.67
# 6  Mickey   15    2.61

# %%
df=pd.DataFrame()
df.empty # bool value to check if df is empty or not
# Out:
# True

# %% [markdown]
# **Statistical or Mathematical Functions**
# Sum
#
#  Mean
#
#  Median
#
#  Mode
#
#  Variance
#
#  Min
#
#  Max
#
#  Standard Deviation

# %%
data={ 'one' : pd.Series([1,2,3,4]) ,
      'two' : pd.Series([10,20,30,40]) ,
      'three' : pd.Series([100,200,300,400]) ,
      'four' : pd.Series([1000,2000,3000,4000])
      }
df= pd.DataFrame(data)
df
# Out:
#    one  two  three  four
# 0    1   10    100  1000
# 1    2   20    200  2000
# 2    3   30    300  3000
# 3    4   40    400  4000

# %%
df.sum()
# Out:
# one         10
# two        100
# three     1000
# four     10000
# dtype: int64

# %%
df.mean()
# Out:
# one         2.5
# two        25.0
# three     250.0
# four     2500.0
# dtype: float64

# %%
df.median()
# Out:
# one         2.5
# two        25.0
# three     250.0
# four     2500.0
# dtype: float64

# %%
de = pd.DataFrame({'A': [1, 2, 2, 3, 4, 4, 4, 5], 'B': [10, 20, 20, 30, 40, 40, 50, 60]})

print('A' , de['A'].mode())
print('B' , de['B'].mode())
# Out:
# A 0    4
# Name: A, dtype: int64
# B 0    20
# 1    40
# Name: B, dtype: int64

# %%
df.var()
# Out:
# one      1.666667e+00
# two      1.666667e+02
# three    1.666667e+04
# four     1.666667e+06
# dtype: float64

# %%
df.min()
# Out:
# one         1
# two        10
# three     100
# four     1000
# dtype: int64

# %%
df.max()
# Out:
# one         4
# two        40
# three     400
# four     4000
# dtype: int64

# %%
df.std()
# Out:
# one         1.290994
# two        12.909944
# three     129.099445
# four     1290.994449
# dtype: float64

# %% [markdown]
# **Describe Function**

# %%
data = {'one'  : pd.Series([1, 2, 3, 4]),
        'two'  : pd.Series([10, 20, 30, 40]),
        'three': pd.Series([100, 200, 300, 400]),
        'four' : pd.Series([1000, 2000, 3000, 4000]),
        'five' : pd.Series(['A','B','C','D'])}


df = pd.DataFrame(data)

df.describe()
# Out:
#             one        two       three         four
# count  4.000000   4.000000    4.000000     4.000000
# mean   2.500000  25.000000  250.000000  2500.000000
# std    1.290994  12.909944  129.099445  1290.994449
# min    1.000000  10.000000  100.000000  1000.000000
# 25%    1.750000  17.500000  175.000000  1750.000000
# 50%    2.500000  25.000000  250.000000  2500.000000
# 75%    3.250000  32.500000  325.000000  3250.000000
# max    4.000000  40.000000  400.000000  4000.000000

# %% [markdown]
# **Pipe Functions**

# %%
data = {'one'  : pd.Series([1, 2, 3, 4]),
        'two'  : pd.Series([10, 20, 30, 40]),
        'three': pd.Series([100, 200, 300, 400]),
        'four' : pd.Series([1000, 2000, 3000, 4000])}

df = pd.DataFrame(data)
df
# Out:
#    one  two  three  four
# 0    1   10    100  1000
# 1    2   20    200  2000
# 2    3   30    300  3000
# 3    4   40    400  4000

# %%
def add_(i,j):
  return i + j

df.pipe(add_ ,10) # i which it gets from table j which will be 10
# Out:
#    one  two  three  four
# 0   11   20    110  1010
# 1   12   30    210  2010
# 2   13   40    310  3010
# 3   14   50    410  4010

# %%
def mean_(col):
  return col.mean()

def square(i):
    return i ** 2
df.pipe(mean_).pipe(square)
# Out:
# one            6.25
# two          625.00
# three      62500.00
# four     6250000.00
# dtype: float64

# %% [markdown]
# **APPLY FUNCTION**

# %%
data = {'one'  : pd.Series([1, 2, 3, 4]),
        'two'  : pd.Series([10, 20, 30, 40]),
        'three': pd.Series([100, 200, 300, 400]),
        'four' : pd.Series([1000, 2000, 3000, 4000])}

df = pd.DataFrame(data)
df

print(df.apply(np.mean))
# Out:
# one         2.5
# two        25.0
# three     250.0
# four     2500.0
# dtype: float64

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# one         3
# two        30
# three     300
# four     3000
# dtype: int64

# %%
df.applymap(lambda x : x*100)
# Out:
# <ipython-input-50-3fa34ac73c87>:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(lambda x : x*100)
#    one   two  three    four
# 0  100  1000  10000  100000
# 1  200  2000  20000  200000
# 2  300  3000  30000  300000
# 3  400  4000  40000  400000

# %%
df = pd.DataFrame({ 'A': [1.2, 3.4, 5.6],
                    'B': [7.8, 9.1, 2.3]})

df_1 = df.applymap(np.int64) # to target specific column
print(df_1)

df_2 = df.apply(lambda row : row.mean(), axis = 0)
print(df_2)
# Out:
#    A  B
# 0  1  7
# 1  3  9
# 2  5  2
# A    3.4
# B    6.4
# dtype: float64
# <ipython-input-51-32fd495afb3d>:4: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df_1 = df.applymap(np.int64) # to target specific column

# %% [markdown]
# **Reindex**

# %%
data = { 'one'   : pd.Series([1, 2, 3, 4]),
         'two'   : pd.Series([10, 20, 30, 40]),
         'three' : pd.Series([100, 200, 300, 400]),
         'four'  : pd.Series([1000, 2000, 3000, 4000])}

df = pd.DataFrame(data)

print(df)
print('-'*30)
print(df.reindex([1,0,3,2]))
# Out:
#    one  two  three  four
# 0    1   10    100  1000
# 1    2   20    200  2000
# 2    3   30    300  3000
# 3    4   40    400  4000
# ------------------------------
#    one  two  three  four
# 1    2   20    200  2000
# 0    1   10    100  1000
# 3    4   40    400  4000
# 2    3   30    300  3000

# %%
data = {'Name' : ['John', 'Jane', 'Jim', 'Joan'],
        'Age'  : [25, 30, 35, 40],
        'City' : ['New York', 'Los Angeles', 'Chicago', 'Houston']}

df = pd.DataFrame(data)

df.reindex(columns = ['Name','City','Age'])
# Out:
#    Name         City  Age
# 0  John     New York   25
# 1  Jane  Los Angeles   30
# 2   Jim      Chicago   35
# 3  Joan      Houston   40

# %% [markdown]
# **Renaming Columns in Pandas DataFrame**

# %%
data = { 'one'   : pd.Series([1, 2, 3, 4]),
         'two'   : pd.Series([10, 20, 30, 40]),
         'three' : pd.Series([100, 200, 300, 400]),
         'four'  : pd.Series([1000, 2000, 3000, 4000])}

df = pd.DataFrame(data)

df.rename(columns = {'one' : 'One','two': 'Two', 'three' : 'Three', 'four' : 'Four'},
           inplace = True, index = {0:'a',1:'b',2:'c',4:'d'})
df
# Out:
#    One  Two  Three  Four
# a    1   10    100  1000
# b    2   20    200  2000
# c    3   30    300  3000
# 3    4   40    400  4000

# %% [markdown]
# **Sorting in Pandas DataFrame**

# %%
data = { 'one'   : pd.Series([11, 51, 31, 41]),
         'two'   : pd.Series([10, 20, 30, 40]),
         'three' : pd.Series([100, 200, 500, 400]),
         'four'  : pd.Series([1000, 2000, 3000, 4000])}

df = pd.DataFrame(data)
df
# Out:
#    one  two  three  four
# 0   11   10    100  1000
# 1   51   20    200  2000
# 2   31   30    500  3000
# 3   41   40    400  4000

# %%
df.sort_values(by = 'one')
# Out:
#    one  two  three  four
# 0   11   10    100  1000
# 2   31   30    500  3000
# 3   41   40    400  4000
# 1   51   20    200  2000

# %%
df.sort_values(by = 'one', ascending = False)
# Out:
#    one  two  three  four
# 1   51   20    200  2000
# 3   41   40    400  4000
# 2   31   30    500  3000
# 0   11   10    100  1000

# %%
df.sort_values(['one','two'])
# Out:
#    one  two  three  four
# 0   11   10    100  1000
# 2   31   30    500  3000
# 3   41   40    400  4000
# 1   51   20    200  2000

# %%
df.sort_values( by ='one' , kind = 'mergesort') # quicksort , heapsort are also there
# Out:
#    one  two  three  four
# 0   11   10    100  1000
# 2   31   30    500  3000
# 3   41   40    400  4000
# 1   51   20    200  2000

# %% [markdown]
# **Groupby Functions**

# %%
cricket = {'Team'   : ['India', 'India', 'Australia', 'Australia', 'SA', 'SA', 'SA', 'SA', 'NZ', 'NZ', 'NZ', 'India'],
           'Rank'   : [2, 3, 1,2, 3,4 ,1 ,1,2 , 4,1,2],
           'Year'   : [2014,2015,2014,2015,2014,2015,2016,2017,2016,2014,2015,2017],
           'Points' : [876,801,891,815,776,784,834,824,758,691,883,782]}

df = pd.DataFrame(cricket)
df
# Out:
#          Team  Rank  Year  Points
# 0       India     2  2014     876
# 1       India     3  2015     801
# 2   Australia     1  2014     891
# 3   Australia     2  2015     815
# 4          SA     3  2014     776
# 5          SA     4  2015     784
# 6          SA     1  2016     834
# 7          SA     1  2017     824
# 8          NZ     2  2016     758
# 9          NZ     4  2014     691
# 10         NZ     1  2015     883
# 11      India     2  2017     782

# %%
df.groupby('Team').groups
# Out:
# {'Australia': [2, 3], 'India': [0, 1, 11], 'NZ': [8, 9, 10], 'SA': [4, 5, 6, 7]}

# %%
df.groupby(['Team' , 'Year']).get_group(('Australia' , 2014))
# Out:
#         Team  Rank  Year  Points
# 2  Australia     1  2014     891

# %%
df.groupby('Team').sum()['Points']
# Out:
# Team
# Australia    1706
# India        2459
# NZ           2332
# SA           3218
# Name: Points, dtype: int64

# %%
df.groupby('Team').sum()['Points'].sort_values(ascending = False)
# Out:
# Team
# SA           3218
# India        2459
# NZ           2332
# Australia    1706
# Name: Points, dtype: int64

# %%
groups=df.groupby('Team')
type(groups['Points']) # as it is a series we can perform agg
groups['Points'].agg([np.sum , np.mean, np.std , np.sum , np.max , np.min])
# Out:
# <ipython-input-72-c9f445972b65>:3: FutureWarning: The provided callable <function sum at 0x78767031ee60> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   groups['Points'].agg([np.sum , np.mean, np.std , np.sum , np.max , np.min])
# <ipython-input-72-c9f445972b65>:3: FutureWarning: The provided callable <function mean at 0x78767031fd90> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   groups['Points'].agg([np.sum , np.mean, np.std , np.sum , np.max , np.min])
# <ipython-input-72-c9f445972b65>:3: FutureWarning: The provided callable <function std at 0x78767031feb0> is currently using SeriesGroupBy.std. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "std" instead.
#   groups['Points'].agg([np.sum , np.mean, np.std , np.sum , np.max , np.min])
# <ipython-input-72-c9f445972b65>:3: FutureWarning: The provided callable <function sum at 0x78767031ee60> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   groups['Points'].agg([np.sum , np.mean, np.std , np.sum , np.max , np.min])
# <ipython-input-72-c9f445972b65>:3: FutureWarning: The provided callable <function max at 0x78767031f490> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   groups['Points'].agg([np.sum , np.mean, np.std , np.sum , np.max , np.min])
# <ipython-input-72-c9f445972b65>:3: FutureWarning: The provided callable <function min at 0x78767031f5b0> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   groups['Points'].agg([np.sum , np.mean, np.std , np.sum , np.max , np.min])
#             sum        mean        std   sum  max  min
# Team
# Australia  1706  853.000000  53.740115  1706  891  815
# India      2459  819.666667  49.702448  2459  876  782
# NZ         2332  777.333333  97.449132  2332  883  691
# SA         3218  804.500000  28.769196  3218  834  776

# %%
df.groupby('Team').filter(lambda x : len(x)==4) # data which is presented 4 times
# Out:
#   Team  Rank  Year  Points
# 4   SA     3  2014     776
# 5   SA     4  2015     784
# 6   SA     1  2016     834
# 7   SA     1  2017     824

# %%
df.groupby('Team').filter(lambda x : len(x) == 3)
# Out:
#      Team  Rank  Year  Points
# 0   India     2  2014     876
# 1   India     3  2015     801
# 8      NZ     2  2016     758
# 9      NZ     4  2014     691
# 10     NZ     1  2015     883
# 11  India     2  2017     782
